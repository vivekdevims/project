# %% [markdown]
# <a href="https://colab.research.google.com/github/vivekdevims/project/blob/main/Copy_of_pandas_student_placement_practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Student Placement Data Analysis using Pandas
#
# This notebook helps you practice real-world **Pandas Data Analysis** tasks using the dataset `student_placement_data.csv`.
#
# Each question builds your understanding step-by-step.
#
# ---

# %% [markdown]
# ### 1️⃣ Load and Explore the Dataset
# Load the dataset and display the first 5 rows to get an overview.

# %%
from google.colab import drive
drive.mount('/content/drive')

import pandas as pd


df=pd.read_csv('/content/drive/MyDrive/Copy of student_placement_data (1).csv')
df.head(5)
df.columns
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Index(['Student_ID', 'Student_Name', 'Course', 'Assignment_Completion_%',
#        'Content_Score_Avg', 'Communication_Skill_(10)', 'Batch_Start_Date',
#        'Placed', 'CTC_LPA'],
#       dtype='object')

# %% [markdown]
# ### 2️⃣ Find the average CTC for each course
# Group the data by `Course` and find the **average CTC_LPA** for placed students.

# %%
CTC_AVERAGE=df.groupby('Course')['CTC_LPA'].mean()
# Out:
# Course
# Data Analytics        5.990625
# Full Stack Web Dev    6.177105
# Python DA             6.472051
# Name: CTC_LPA, dtype: float64

# %% [markdown]
# ### 3️⃣ Compare average communication skill between placed and unplaced students
# Find average `Communication_Skill_(10)` for both placed and unplaced students.

# %%
COMMUNICATION=df.groupby('Placed')['Communication_Skill_(10)'].mean()
COMMUNICATION
# Out:
# Placed
# No     6.073171
# Yes    6.825688
# Name: Communication_Skill_(10), dtype: float64

# %% [markdown]
# ### 4️⃣ Find top 10 students by assignment completion percentage
# Sort the data by `Assignment_Completion_%` in descending order and display top 10 students.

# %%
ASSIGNMENT=df.sort_values(by='Assignment_Completion_%',ascending=False)
ASSIGNMENT.head(10)
# Out:
#     Student_ID   Student_Name              Course  Assignment_Completion_%  \
# 136     STU137    Myra Sharma           Python DA                       99
# 41      STU042    Aarav Reddy  Full Stack Web Dev                       99
# 78      STU079    Meera Singh           Python DA                       98
# 75      STU076      Ira Verma      Data Analytics                       98
# 19      STU020  Reyansh Gupta  Full Stack Web Dev                       97
# 13      STU014     Aarav Nair  Full Stack Web Dev                       97
# 57      STU058       Diya Das           Python DA                       97
# 99      STU100   Aadhya Gupta  Full Stack Web Dev                       97
# 1       STU002    Anika Patel  Full Stack Web Dev                       96
# 42      STU043     Aarav Nair  Full Stack Web Dev                       96
#
#      Content_Score_Avg  Communication_Skill_(10) Batch_Start_Date Placed  \
# ...

# %% [markdown]
# ### 5️⃣ Group by course and check placement rate
# Find how many students are placed and not placed in each course.

# %%
PLACEMENT=df.groupby('Course')['Placed'].value_counts()
#
# Out:
# Course              Placed
# Data Analytics      Yes       32
#                     No        22
# Full Stack Web Dev  Yes       38
#                     No        10
# Python DA           Yes       39
#                     No         9
# Name: count, dtype: int64

# %% [markdown]
# ### 6️⃣ (Optional Challenge) Find high-performing students not placed
# Find students who scored `>80` in content score and `>8` in communication skills but are **not placed**.

# %%
#NOT_PLACED=df[(df['Contest_Score_Avg']>80) & (df['Communication_Skill_(10)']>8) & (df['Placed']==0) ]
display(df[(df['Content_Score_Avg']>80) & (df['Communication_Skill_(10)']>8) & (df['Placed']=='No')])
# Out:
#    Student_ID Student_Name     Course  Assignment_Completion_%  \
# 48     STU049  Arjun Kumar  Python DA                       53
#
#     Content_Score_Avg  Communication_Skill_(10) Batch_Start_Date Placed  \
# 48                 83                        10       2024-10-22     No
#
#     CTC_LPA
# 48      NaN

# %%
df['CTC_LPA'] = df['CTC_LPA'].fillna(0)
# Out:
#     Student_ID    Student_Name              Course  Assignment_Completion_%  \
# 0       STU001      Ishaan Das      Data Analytics                       83
# 1       STU002     Anika Patel  Full Stack Web Dev                       96
# 2       STU003    Aditya Kumar  Full Stack Web Dev                       73
# 3       STU004    Aditya Verma  Full Stack Web Dev                       59
# 4       STU005  Krishna Sharma  Full Stack Web Dev                       87
# ..         ...             ...                 ...                      ...
# 145     STU146  Muhammad Reddy      Data Analytics                       79
# 146     STU147       Anika Das  Full Stack Web Dev                       45
# 147     STU148   Krishna Singh      Data Analytics                       79
# 148     STU149      Myra Gupta  Full Stack Web Dev                       81
# 149     STU150    Anika Sharma      Data Analytics                       91
#
# ...

# %% [markdown]
# minimum score of placed student in both Contest_score and Communication skill.

# %%
# Find minimum values
min_content = df['Content_Score_Avg'].min()
min_communication = df['Communication_Skill_(10)'].min()

# Filter rows
Minimum = df[
    (df['Content_Score_Avg'] == min_content) &
    (df['Communication_Skill_(10)'] == min_communication) &
    (df['Placed'] == 'Yes')
]

display(Minimum)
# Out:
# Empty DataFrame
# Columns: [Student_ID, Student_Name, Course, Assignment_Completion_%, Content_Score_Avg, Communication_Skill_(10), Batch_Start_Date, Placed, CTC_LPA]
# Index: []

# %%
# Placement status distribution
print("🔹 Placement Status (%):")
print(df['Placed'].value_counts(normalize=True) * 100)

# Compare placed vs unplaced
print("\n🔹 Average Performance by Placement Status:")
placement_comparison = df.groupby('Placed')[['Assignment_Completion_%', 'Communication_Skill_(10)', 'Content_Score_Avg']].mean().round(2)
display(placement_comparison)
# Out:
# 🔹 Placement Status (%):
# Placed
# Yes    72.666667
# No     27.333333
# Name: proportion, dtype: float64
#
# 🔹 Average Performance by Placement Status:
#         Assignment_Completion_%  Communication_Skill_(10)  Content_Score_Avg
# Placed
# No                        72.29                      6.07              62.22
# Yes                       71.49                      6.83              73.18
